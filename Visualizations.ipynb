# %%
import matplotlib.pyplot as plt

# Data from the tables without 2:4 structured pruning (0.5 sparsity)

# Updated Sparsity Levels (without 0.5)
sparsity_levels = [0, 0.2, 0.4, 0.6, 0.8]  # 0 is baseline

# Phi-2 Model Data
phi2_accuracy_csqa = [57.49, 56.02, 49.63, 36.04, 17.85]
phi2_f1_csqa = [57.48, 55.99, 49.63, 36.02, 17.84]

phi2_accuracy_cqa = [30.95, 34.51, 34.47, 30.32, 19.13]
phi2_f1_cqa = [30.96, 34.49, 34.45, 30.30, 19.12]

phi2_accuracy_lqa = [21.20, 20.74, 19.66, 18.74, 17.97]
phi2_f1_lqa = [20.63, 20.27, 18.82, 18.12, 18.24]

phi2_accuracy_reclor = [22.00, 20.40, 20.80, 20.60, 17.00]
phi2_f1_reclor = [22.07, 20.49, 20.92, 20.71, 17.08]

phi2_accuracy_ekar = [33.05, 33.90, 38.14, 33.90, 27.97]
phi2_f1_ekar = [32.08, 33.47, 38.19, 33.63, 27.99]

# Phi-3 Model Data
phi3_accuracy_csqa = [48.40, 47.58, 43.49, 32.27, 15.23]
phi3_f1_csqa = [48.45, 47.61, 43.50, 32.18, 15.23]

phi3_accuracy_cqa = [31.93, 32.33, 37.22, 28.31, 20.03]
phi3_f1_cqa = [31.93, 32.33, 37.21, 28.29, 20.03]

phi3_accuracy_lqa = [21.81, 21.81, 21.04, 20.28, 18.74]
phi3_f1_lqa = [21.02, 21.27, 20.77, 19.14, 18.91]

phi3_accuracy_reclor = [22.60, 24.00, 22.80, 20.80, 17.00]
phi3_f1_reclor = [22.69, 24.04, 23.01, 20.91, 17.10]

phi3_accuracy_ekar = [37.29, 38.98, 40.68, 26.27, 26.27]
phi3_f1_ekar = [37.48, 39.00, 40.97, 26.22, 26.22]

# Plotting the data
plt.figure(figsize=(16, 20))

# CommonsenseQA Accuracy Graph
plt.subplot(5, 2, 1)
plt.plot(sparsity_levels, phi2_accuracy_csqa, marker='o', label='Phi-2')
plt.plot(sparsity_levels, phi3_accuracy_csqa, marker='o', label='Phi-3 Mini')
plt.title('CommonsenseQA Accuracy at Different Sparsity Levels')
plt.xlabel('Sparsity Level')
plt.ylabel('Accuracy (%)')
plt.xticks(sparsity_levels, labels=['Base', '0.2', '0.4', '0.6', '0.8'])
plt.legend()

# CommonsenseQA F1 Score Graph
plt.subplot(5, 2, 2)
plt.plot(sparsity_levels, phi2_f1_csqa, marker='o', label='Phi-2')
plt.plot(sparsity_levels, phi3_f1_csqa, marker='o', label='Phi-3 Mini')
plt.title('CommonsenseQA F1 Score at Different Sparsity Levels')
plt.xlabel('Sparsity Level')
plt.ylabel('F1 Score (%)')
plt.xticks(sparsity_levels, labels=['Base', '0.2', '0.4', '0.6', '0.8'])
plt.legend()

# CosmosQA Accuracy Graph
plt.subplot(5, 2, 3)
plt.plot(sparsity_levels, phi2_accuracy_cqa, marker='o', label='Phi-2')
plt.plot(sparsity_levels, phi3_accuracy_cqa, marker='o', label='Phi-3 Mini')
plt.title('CosmosQA Accuracy at Different Sparsity Levels')
plt.xlabel('Sparsity Level')
plt.ylabel('Accuracy (%)')
plt.xticks(sparsity_levels, labels=['Base', '0.2', '0.4', '0.6', '0.8'])
plt.legend()

# CosmosQA F1 Score Graph
plt.subplot(5, 2, 4)
plt.plot(sparsity_levels, phi2_f1_cqa, marker='o', label='Phi-2')
plt.plot(sparsity_levels, phi3_f1_cqa, marker='o', label='Phi-3 Mini')
plt.title('CosmosQA F1 Score at Different Sparsity Levels')
plt.xlabel('Sparsity Level')
plt.ylabel('F1 Score (%)')
plt.xticks(sparsity_levels, labels=['Base', '0.2', '0.4', '0.6', '0.8'])
plt.legend()

# LogiQA Accuracy Graph
plt.subplot(5, 2, 5)
plt.plot(sparsity_levels, phi2_accuracy_lqa, marker='o', label='Phi-2')
plt.plot(sparsity_levels, phi3_accuracy_lqa, marker='o', label='Phi-3 Mini')
plt.title('LogiQA Accuracy at Different Sparsity Levels')
plt.xlabel('Sparsity Level')
plt.ylabel('Accuracy (%)')
plt.xticks(sparsity_levels, labels=['Base', '0.2', '0.4', '0.6', '0.8'])
plt.legend()

# LogiQA F1 Score Graph
plt.subplot(5, 2, 6)
plt.plot(sparsity_levels, phi2_f1_lqa, marker='o', label='Phi-2')
plt.plot(sparsity_levels, phi3_f1_lqa, marker='o', label='Phi-3 Mini')
plt.title('LogiQA F1 Score at Different Sparsity Levels')
plt.xlabel('Sparsity Level')
plt.ylabel('F1 Score (%)')
plt.xticks(sparsity_levels, labels=['Base', '0.2', '0.4', '0.6', '0.8'])
plt.legend()

# ReClor Accuracy Graph
plt.subplot(5, 2, 7)
plt.plot(sparsity_levels, phi2_accuracy_reclor, marker='o', label='Phi-2')
plt.plot(sparsity_levels, phi3_accuracy_reclor, marker='o', label='Phi-3 Mini')
plt.title('ReClor Accuracy at Different Sparsity Levels')
plt.xlabel('Sparsity Level')
plt.ylabel('Accuracy (%)')
plt.xticks(sparsity_levels, labels=['Base', '0.2', '0.4', '0.6', '0.8'])
plt.legend()

# ReClor F1 Score Graph
plt.subplot(5, 2, 8)
plt.plot(sparsity_levels, phi2_f1_reclor, marker='o', label='Phi-2')
plt.plot(sparsity_levels, phi3_f1_reclor, marker='o', label='Phi-3 Mini')
plt.title('ReClor F1 Score at Different Sparsity Levels')
plt.xlabel('Sparsity Level')
plt.ylabel('F1 Score (%)')
plt.xticks(sparsity_levels, labels=['Base', '0.2', '0.4', '0.6', '0.8'])
plt.legend()

# E-KAR Accuracy Graph
plt.subplot(5, 2, 9)
plt.plot(sparsity_levels, phi2_accuracy_ekar, marker='o', label='Phi-2')
plt.plot(sparsity_levels, phi3_accuracy_ekar, marker='o', label='Phi-3 Mini')
plt.title('E-KAR Accuracy at Different Sparsity Levels')
plt.xlabel('Sparsity Level')
plt.ylabel('Accuracy (%)')
plt.xticks(sparsity_levels, labels=['Base', '0.2', '0.4', '0.6', '0.8'])
plt.legend()

# E-KAR F1 Score Graph
plt.subplot(5, 2, 10)
plt.plot(sparsity_levels, phi2_f1_ekar, marker='o', label='Phi-2')
plt.plot(sparsity_levels, phi3_f1_ekar, marker='o', label='Phi-3 Mini')
plt.title('E-KAR F1 Score at Different Sparsity Levels')
plt.xlabel('Sparsity Level')
plt.ylabel('F1 Score (%)')
plt.xticks(sparsity_levels, labels=['Base', '0.2', '0.4', '0.6', '0.8'])
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data specifically for 0.5 sparsity level (2:4 structured pruning)

# Phi-2 Model Data at 0.5 Sparsity
phi2_0_5_csqa = 36.20
phi2_0_5_cqa = 30.52
phi2_0_5_lqa = 19.05
phi2_0_5_reclor = 19.00
phi2_0_5_ekar = 32.20

# Phi-3 Mini Model Data at 0.5 Sparsity
phi3_0_5_csqa = 31.45
phi3_0_5_cqa = 28.68
phi3_0_5_lqa = 20.89
phi3_0_5_reclor = 21.40
phi3_0_5_ekar = 33.90

# Accuracy comparison at 0.5 Sparsity
tasks = ['CommonsenseQA', 'CosmosQA', 'LogiQA', 'ReClor', 'E-KAR']
phi2_accuracies = [phi2_0_5_csqa, phi2_0_5_cqa, phi2_0_5_lqa, phi2_0_5_reclor, phi2_0_5_ekar]
phi3_accuracies = [phi3_0_5_csqa, phi3_0_5_cqa, phi3_0_5_lqa, phi3_0_5_reclor, phi3_0_5_ekar]

# Plotting the accuracy comparison for 0.5 Sparsity
plt.figure(figsize=(10, 6))
plt.bar(tasks, phi2_accuracies, width=0.4, label='Phi-2', align='center')
plt.bar(tasks, phi3_accuracies, width=0.4, label='Phi-3 Mini', align='edge')
plt.title('Accuracy Comparison at 0.5 Sparsity (2:4 Structured Pruning)')
plt.xlabel('Tasks')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()
